# %% [markdown]
# <a href="https://colab.research.google.com/github/mandar-solanki/exercises/blob/main/2604-Applied-Data-Modelling-using-Gradio/0428%201.2%20Gradio%20Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gradio is a Python library used to quickly build interactive web UIs for ML models or functions. It wraps your Python function into a browser-based app with inputs and outputs.
#
# A Gradio app =
# **Function (logic) + Inputs + Outputs + Interface wrapper**
#
# ### Step-by-Step Implementation
# #### 1. Import a install Gradio App

# %%
### pip install gradio
import gradio as gr

# %% [markdown]
# ### 2. Define a Function
#
# This is your core logic.
#
# Example: Simple Addition

# %%
def add_numbers(a, b):
    return a + b

# %% [markdown]
# ### 3. Create Interface

# %%
interface = gr.Interface(
    fn=add_numbers,        # Function
    inputs=["number", "number"],  # Input types
    outputs="number",       # Output type
    title="Sample"
)

# %% [markdown]
# ### 4. Launch App

# %%
interface.launch(share=False, debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
# * To create a public link, set `share=True` in `launch()`.
# Keyboard interruption in main thread... closing server.

# %% [markdown]
# ### Key Parameters of gr.Interface
# - fn (Function)
# The backend logic
# Must accept inputs → return outputs
#
# ### Inputs : Defines UI components:
#
# | Type     | Example       |
# | -------- | ------------- |
# | "text"   | Text input    |
# | "number" | Numeric input |
# | "slider" | Range input   |
# | "image"  | Image upload  |

# %%
inputs=["text"]

# %% [markdown]
# ### outputs: Defines output display
# | Type     | Example        |
# | -------- | -------------- |
# | "text"   | Text result    |
# | "number" | Numeric output |
# | "label"  | Classification |
# | "image"  | Image output   |

# %% [markdown]
# ### title & description

# %%
gr.Interface(
    fn=add_numbers,
    inputs=["number", "number"],
    outputs="number",
    title="Addition App",
    description="Enter two numbers"
)
# Out:
# Gradio Interface for: add_numbers
# ---------------------------------
# inputs:
# |-<gradio.components.number.Number object at 0x7f4255149520>
# |-<gradio.components.number.Number object at 0x7f4255e1c590>
# outputs:
# |-<gradio.components.number.Number object at 0x7f4257ad7e90>

# %% [markdown]
# ### Example: ML Model (Churn Prediction)

# %%
def predict_churn(age, purchase_freq, avg_spend):
    score = age * 0.1 + purchase_freq * -0.5 + avg_spend * 0.01
    return "Churn" if score > 5 else "No Churn"

app = gr.Interface(
    fn=predict_churn,
    inputs=["number", "number", "number"],
    outputs="text",
    title="Customer Churn Predictor"
)

app.launch(share=False)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
# * To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# ## Advanced Components
#
# ### Using Sliders

# %%
inputs=[
    gr.Slider(18, 60),
    gr.Slider(1, 10),
    gr.Slider(100, 1000)
]

# %% [markdown]
# ### Using Dropdown

# %%
gr.Dropdown(["Low", "Medium", "High"])

# %% [markdown]
# ### Using Image Input

# %% [raw]
# gr.Interface(
#     fn=process_image,
#     inputs="image",
#     outputs="image"
# )

# %% [markdown]
# ### Using gr.Blocks (Advanced UI)

# %%
with gr.Blocks() as demo:
    num1 = gr.Number()
    num2 = gr.Number()
    output = gr.Number()

    btn = gr.Button("Add")
    btn.click(fn=add_numbers, inputs=[num1, num2], outputs=output)

demo.launch(share=False)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Note: opening Chrome Inspector may crash demo inside Colab notebooks.
# * To create a public link, set `share=True` in `launch()`.

# %% [markdown]
# ### Deployment Options
# - Local (launch())
# - Shareable link (launch(share=True))
#
# ### Deploy on:
# - Hugging Face Spaces
# - Cloud (AWS / Azure / GCP)
# ###  Summary
# - gr.Interface → Quick UI wrapper
# - fn → Logic
# - inputs/outputs → UI structure
# - launch() → Run app
